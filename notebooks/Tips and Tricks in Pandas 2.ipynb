# %%
#how to create a data frame in pandas

# %%
import pandas as pd
import numpy as np

# %%
#specify column names and values using a dictionary
df = pd.DataFrame({'Resistivity-Ohms': [100,450,230,400],
                   'VES':['Wenner','Schlumberger','Dipole-Dipole', 'Wenner']})

# %%
df
# Out:
#    Resistivity-Ohms            VES
# 0               100         Wenner
# 1               450   Schlumberger
# 2               230  Dipole-Dipole
# 3               400         Wenner

# %%
#create data frame from random values
import pandas as pd
import numpy as np
df_rand = pd.DataFrame(np.random.randn(2,3), columns = ['A','B','C'])

# %%
df_rand
# Out:
#           A         B         C
# 0  1.331637  0.266748  1.379711
# 1  0.433043  1.337425 -1.713523

# %%
#Create data frame from mixed data types
import pandas.util.testing
pd.util.testing.makeTimeDataFrame().head()
#.makeMixedDataFrame and .makeDataFrame
# Out:
#                    A         B         C         D
# 2000-01-03 -0.802057  0.092044  0.667642  1.424638
# 2000-01-04 -0.539003 -0.410572 -0.714754 -0.599529
# 2000-01-05  1.662361 -0.127493  0.085996 -1.737681
# 2000-01-06  0.752296 -0.280160 -0.658885 -0.406089
# 2000-01-07 -0.525944  0.547063 -2.381371 -0.957086

# %% [markdown]
# Need to create a time series dataset for testing?
# Use pd.util.testing.makeTimeDataFrame().
#
# Need more control over the columns & data?
# Generate data with np.random & overwrite index with makeDateIndex().

# %%
num_rows = 1*24 #Number of hours in a day
sales = pd.util.testing.makeTimeDataFrame(num_rows, freq='H')
sales.head()
# Out:
#                             A         B         C         D
# 2000-01-01 00:00:00  0.800189  0.749149 -0.114589  0.438451
# 2000-01-01 01:00:00 -1.774450 -1.377975  1.356092 -0.661794
# 2000-01-01 02:00:00 -1.815057 -0.897161 -0.892818  0.398855
# 2000-01-01 03:00:00 -0.698460 -0.776197 -0.477888 -0.823541
# 2000-01-01 04:00:00 -0.043305  0.710354  1.033290  0.932376

# %%
num_cols = 2 #Specify the number of columns
cols = ['Price of Items($)', 'Number of Items Sold']
df_sales = pd.DataFrame(np.random.randint(1, 200, 
                        size = (num_rows, num_cols)),
                        columns=cols)
df_sales.index = pd.util.testing.makeDateIndex(num_rows, freq = 'H')
df_sales.head()
# Out:
#                      Price of Items($)  Number of Items Sold
# 2000-01-01 00:00:00                122                    82
# 2000-01-01 01:00:00                 23                   105
# 2000-01-01 02:00:00                 19                   164
# 2000-01-01 03:00:00                 76                    40
# 2000-01-01 04:00:00                 96                   104

# %%
import pandas as pd
df = pd.read_csv('../Data/table1.csv')
df
# Out:
#        country  year   cases  population
# 0  Afghanistan  1999     745    19987071
# 1  Afghanistan  2000    2666    20595360
# 2       Brazil  1999   37737   172006362
# 3       Brazil  2000   80488   174504898
# 4        China  1999  212258  1272915272
# 5        China  2000  213766  1280428583

# %%
df.rename({0:'Country'}) #Rename Index
# Out:
#              country  year   cases  population
# Country  Afghanistan  1999     745    19987071
# 1        Afghanistan  2000    2666    20595360
# 2             Brazil  1999   37737   172006362
# 3             Brazil  2000   80488   174504898
# 4              China  1999  212258  1272915272
# 5              China  2000  213766  1280428583

# %%
df
# Out:
#        country  year   cases  population
# 0  Afghanistan  1999     745    19987071
# 1  Afghanistan  2000    2666    20595360
# 2       Brazil  1999   37737   172006362
# 3       Brazil  2000   80488   174504898
# 4        China  1999  212258  1272915272
# 5        China  2000  213766  1280428583

# %%
#Want to create new columns within a data frame? use df.assign()
#let's create new columns for population_decline and percent_cases
p_decline = df.assign(population_decline = df.population/df.cases, 
                          percent_cases= df.cases/df_new.population*100)
p_decline
# Out:
#        country  year   cases  population  population_decline  percent_cases
# 0  Afghanistan  1999     745    19987071        26828.283221       0.003727
# 1  Afghanistan  2000    2666    20595360         7725.191298       0.012945
# 2       Brazil  1999   37737   172006362         4558.029573       0.021939
# 3       Brazil  2000   80488   174504898         2168.085901       0.046124
# 4        China  1999  212258  1272915272         5997.019062       0.016675
# 5        China  2000  213766  1280428583         5989.860796       0.016695

# %%
import seaborn as sns
from IPython.display import HTML
#set color map to sea born light green palette
cm = sns.light_palette('green', as_cmap = True)
(p_decline.style
        .set_caption('Population Decline from 1999 to 2000')
        .background_gradient(cmap=cm, subset = ['population_decline', 'percent_cases'])
        .format({'percent_cases':'{:,.2%}'})
)
# Out:
# <style  type="text/css" >
#     #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col5 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col4 {
#             background-color:  #b2e3b2;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col5 {
#             background-color:  #b4e4b4;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col4 {
#             background-color:  #d0f3d0;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col5 {
#             background-color:  #83c983;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col4 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col5 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col4 {
#             background-color:  #c2ecc2;
#             color:  #000000;
#         }    #T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col5 {
#             background-color:  #9fd89f;
#             color:  #000000;
#         }</style><table id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758" ><caption>Population Decline from 1999 to 2000</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >cases</th>        <th class="col_heading level0 col3" >population</th>        <th class="col_heading level0 col4" >population_decline</th>        <th class="col_heading level0 col5" >percent_cases</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col1" class="data row0 col1" >1999</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col2" class="data row0 col2" >745</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col3" class="data row0 col3" >19987071</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col4" class="data row0 col4" >26828.283221</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row0_col5" class="data row0 col5" >0.37%</td>
#             </tr>
#             <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col0" class="data row1 col0" >Afghanistan</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col1" class="data row1 col1" >2000</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col2" class="data row1 col2" >2666</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col3" class="data row1 col3" >20595360</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col4" class="data row1 col4" >7725.191298</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row1_col5" class="data row1 col5" >1.29%</td>
#             </tr>
#             <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col0" class="data row2 col0" >Brazil</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col1" class="data row2 col1" >1999</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col2" class="data row2 col2" >37737</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col3" class="data row2 col3" >172006362</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col4" class="data row2 col4" >4558.029573</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row2_col5" class="data row2 col5" >2.19%</td>
#             </tr>
#             <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col0" class="data row3 col0" >Brazil</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col1" class="data row3 col1" >2000</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col2" class="data row3 col2" >80488</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col3" class="data row3 col3" >174504898</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col4" class="data row3 col4" >2168.085901</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row3_col5" class="data row3 col5" >4.61%</td>
#             </tr>
#             <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col0" class="data row4 col0" >China</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col1" class="data row4 col1" >1999</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col2" class="data row4 col2" >212258</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col3" class="data row4 col3" >1272915272</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col4" class="data row4 col4" >5997.019062</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row4_col5" class="data row4 col5" >1.67%</td>
#             </tr>
#             <tr>
#                         <th id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col0" class="data row5 col0" >China</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col1" class="data row5 col1" >2000</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col2" class="data row5 col2" >213766</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col3" class="data row5 col3" >1280428583</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col4" class="data row5 col4" >5989.860796</td>
#                         <td id="T_2db6b7a4_84ff_11ea_b121_24f5aacb8758row5_col5" class="data row5 col5" >1.67%</td>
#             </tr>
#     </tbody></table>

# %%
#lets say we want all cases in case column below 3000 colored red, less than 10,000 coloured green and greater than 10,000 coloured black

def color_red(value):
    
    if value < 3000:
        color = 'red'
    elif value > 3000:
        color = 'green'
    else:
        color = 'black'
    
    return 'color:%s' % color
        
#You can then apply this function to your dataframe using the Styler object’s applymap() method:

p_decline.style.applymap(color_red, subset = ['cases'])
# Out:
# <style  type="text/css" >
#     #T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col2 {
#             color: red;
#         }    #T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col2 {
#             color: red;
#         }    #T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col2 {
#             color: green;
#         }    #T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col2 {
#             color: green;
#         }    #T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col2 {
#             color: green;
#         }    #T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col2 {
#             color: green;
#         }</style><table id="T_6fd6a506_8503_11ea_be75_24f5aacb8758" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >country</th>        <th class="col_heading level0 col1" >year</th>        <th class="col_heading level0 col2" >cases</th>        <th class="col_heading level0 col3" >population</th>        <th class="col_heading level0 col4" >population_decline</th>        <th class="col_heading level0 col5" >percent_cases</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col0" class="data row0 col0" >Afghanistan</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col1" class="data row0 col1" >1999</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col2" class="data row0 col2" >745</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col3" class="data row0 col3" >19987071</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col4" class="data row0 col4" >26828.283221</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row0_col5" class="data row0 col5" >0.003727</td>
#             </tr>
#             <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col0" class="data row1 col0" >Afghanistan</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col1" class="data row1 col1" >2000</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col2" class="data row1 col2" >2666</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col3" class="data row1 col3" >20595360</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col4" class="data row1 col4" >7725.191298</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row1_col5" class="data row1 col5" >0.012945</td>
#             </tr>
#             <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col0" class="data row2 col0" >Brazil</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col1" class="data row2 col1" >1999</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col2" class="data row2 col2" >37737</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col3" class="data row2 col3" >172006362</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col4" class="data row2 col4" >4558.029573</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row2_col5" class="data row2 col5" >0.021939</td>
#             </tr>
#             <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col0" class="data row3 col0" >Brazil</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col1" class="data row3 col1" >2000</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col2" class="data row3 col2" >80488</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col3" class="data row3 col3" >174504898</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col4" class="data row3 col4" >2168.085901</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row3_col5" class="data row3 col5" >0.046124</td>
#             </tr>
#             <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col0" class="data row4 col0" >China</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col1" class="data row4 col1" >1999</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col2" class="data row4 col2" >212258</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col3" class="data row4 col3" >1272915272</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col4" class="data row4 col4" >5997.019062</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row4_col5" class="data row4 col5" >0.016675</td>
#             </tr>
#             <tr>
#                         <th id="T_6fd6a506_8503_11ea_be75_24f5aacb8758level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col0" class="data row5 col0" >China</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col1" class="data row5 col1" >2000</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col2" class="data row5 col2" >213766</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col3" class="data row5 col3" >1280428583</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col4" class="data row5 col4" >5989.860796</td>
#                         <td id="T_6fd6a506_8503_11ea_be75_24f5aacb8758row5_col5" class="data row5 col5" >0.016695</td>
#             </tr>
#     </tbody></table>

# %%
#Need to create a bunch of new columns based on existing columns? Use this pattern:

#for col in df.columns:
   # df[f'{col}_new'] = df[col].apply(my_function)
    
cities = pd.DataFrame({'State':['NY', 'az', 'cA', 'Ok'], 'counTRY': ['Us', 'us','us','uS']})
cities
# Out:
#   State counTRY
# 0    NY      Us
# 1    az      us
# 2    cA      us
# 3    Ok      uS

# %%
for col in cities.columns:
    cities[f'{col}'] = cities[col].str.upper()

# %%
cities
# Out:
#   State_fixed counTRY_fixed State_fixed_fixed counTRY_fixed_fixed  \
# 0          NY            US                NY                  US
# 1          AZ            US                AZ                  US
# 2          CA            US                CA                  US
# 3          OK            US                OK                  US
#
#   State_fixed_fixed_fixed counTRY_fixed_fixed_fixed  \
# 0                      NY                        US
# 1                      AZ                        US
# 2                      CA                        US
# 3                      OK                        US
#
#   State_fixed_fixed_fixed_fixed counTRY_fixed_fixed_fixed_fixed
# 0                            NY                              US
# 1                            AZ                              US
# 2                            CA                              US
# 3                            OK                              US

# %%
cities.pop('counTRY_fixed_fixed_fixed_fixed')
# Out:
# 0    US
# 1    US
# 2    US
# 3    US
# Name: counTRY_fixed_fixed_fixed_fixed, dtype: object

# %%
cities
# Out:
#   State_fixed counTRY_fixed State_fixed_fixed counTRY_fixed_fixed  \
# 0          NY            US                NY                  US
# 1          AZ            US                AZ                  US
# 2          CA            US                CA                  US
# 3          OK            US                OK                  US
#
#   State_fixed_fixed_fixed counTRY_fixed_fixed_fixed  \
# 0                      NY                        US
# 1                      AZ                        US
# 2                      CA                        US
# 3                      OK                        US
#
#   State_fixed_fixed_fixed_fixed
# 0                            NY
# 1                            AZ
# 2                            CA
# 3                            OK

# %%
import pandas as pd
import numpy as np
groceries = pd.DataFrame(np.array([[10,20,30], 
                                   [20,50,70], 
                                   [40,60,90]]), 
                   columns= ['Hostel_A', 'Hostel_B', 'Hostel_C'], 
                   index= ['Sugar', 'Milk', 'Chocolate'])

# %%
groceries
# Out:
#            Hostel_A  Hostel_B  Hostel_C
# Sugar            10        20        30
# Milk             20        50        70
# Chocolate        40        60        90

# %%
df2
# Out:
#            A  B  C
# Sugar      1  2  3
# Milk       2  5  7
# Chocolate  4  6  7

# %%
#3 ways to rename columns:

#1. Most flexible option:
#df = df.rename({'A':'a', 'B':'b'}, axis='columns')

#2. Overwrite all column names:
#df.columns = ['a', 'b']

#3. Apply string method:
#df.columns = df.columns.str.lower()

# %%
df2
# Out:
#            A  B  C
# Sugar      1  2  3
# Milk       2  5  7
# Chocolate  4  6  7

# %%
#flexible option to rename columns and index
df2_rename = df2.rename(columns = {'A':'price($)', 
                                   'B': 'customers', 
                                   'C': 'Quantity'}, 
                        index = {'Milo': 'Ovaltine'}) 
df2_rename
# Out:
#            price($)  customers  Quantity
# Sugar             1          2         3
# Milk              2          5         7
# Chocolate         4          6         7

# %%
groceries
# Out:
#            Hostel_A  Hostel_B  Hostel_C
# Sugar            10        20        30
# Milk             20        50        70
# Chocolate        40        60        90

# %%
groceries.rename(columns = str.upper)
# Out:
#            HOSTEL_A  HOSTEL_B  HOSTEL_C
# Sugar            10        20        30
# Milk             20        50        70
# Chocolate        40        60        90

# %%
#we can also use the Lambda function

df2_rename.rename(index = lambda s: s + '750g')
# Out:
#                price($)  customers  Quantity
# Ovaltine750g          1          2         3
# Milk750g              2          5         7
# Chocolate750g         4          6         7

# %%
df2_rename
# Out:
#            price($)  customers  Quantity
# Sugar             1          2         3
# Milk              2          5         7
# Chocolate         4          6         7

# %%
#add prefix to data frame in all columns
df2_rename.add_prefix('item_')
# Out:
#            item_price($)  item_customers  item_Quantity
# Sugar                  1               2              3
# Milk                   2               5              7
# Chocolate              4               6              7

# %%
#add suffix to data frame in all columns
df2_rename.add_suffix('_item')
# Out:
#            price($)_item  customers_item  Quantity_item
# Sugar                  1               2              3
# Milk                   2               5              7
# Chocolate              4               6              7

# %%
df2_rename
# Out:
#            price($)  customers  Quantity
# Ovaltine          1          2         3
# Milk              2          5         7
# Chocolate         4          6         7

# %%
df3 = df2_rename.customers.reset_index()

# %%
df3.iloc[2]
# Out:
# index        Chocolate
# customers            6
# Name: 2, dtype: object

# %%
# Out:
#            price($)  customers  Quantity
# Ovaltine          1          2         3
# Milk              2          5         7
# Chocolate         4          6         7

# %%
df2_rename.shape
# Out:
# (3, 3)

# %%
#Want to filter a DataFrame to only include the largest categories?

#1. Save the value_counts() output
#2. Get the index of its head()
#3. Use that index with isin() to filter the DataFrame

import pandas as pd
df = pd.read_html('https://en.wikipedia.org/wiki/List_of_most-followed_Twitter_accounts')
df[0].head()
# Out:
#    Rank  Change (monthly)   Account name              Owner  \
# 0     1               NaN   @BarackObama       Barack Obama
# 1     2               NaN  @justinbieber      Justin Bieber
# 2     3               NaN     @katyperry         Katy Perry
# 3     4               NaN       @rihanna            Rihanna
# 4     5               NaN     @Cristiano  Cristiano Ronaldo
#
#    Followers (millions)                    Activity
# 0                   121       Former U.S. president
# 1                   112                    Musician
# 2                   108                    Musician
# 3                    98  Musician and businesswoman
# 4                    87             Football player

# %%
df_new = pd.concat([df[0], df[1]])
df_new.head()
# Out:
#    Rank  Change (monthly)   Account name              Owner  \
# 0   1.0               NaN   @BarackObama       Barack Obama
# 1   2.0               NaN  @justinbieber      Justin Bieber
# 2   3.0               NaN     @katyperry         Katy Perry
# 3   4.0               NaN       @rihanna            Rihanna
# 4   5.0               NaN     @Cristiano  Cristiano Ronaldo
#
#    Followers (millions)                    Activity vteTwitter vteTwitter.1
# 0                 121.0       Former U.S. president        NaN          NaN
# 1                 112.0                    Musician        NaN          NaN
# 2                 108.0                    Musician        NaN          NaN
# 3                  98.0  Musician and businesswoman        NaN          NaN
# 4                  87.0             Football player        NaN          NaN

# %%
df_new['vteTwitter'].fillna('Not Available', inplace=True)
df_new['vteTwitter.1'].fillna('Not Available', inplace=True)

# %%
df_new.head()
# Out:
#    Rank  Change (monthly)   Account name              Owner  \
# 0   1.0               NaN   @BarackObama       Barack Obama
# 1   2.0               NaN  @justinbieber      Justin Bieber
# 2   3.0               NaN     @katyperry         Katy Perry
# 3   4.0               NaN       @rihanna            Rihanna
# 4   5.0               NaN     @Cristiano  Cristiano Ronaldo
#
#    Followers (millions)                    Activity     vteTwitter  \
# 0                 121.0       Former U.S. president  Not Available
# 1                 112.0                    Musician  Not Available
# 2                 108.0                    Musician  Not Available
# 3                  98.0  Musician and businesswoman  Not Available
# 4                  87.0             Football player  Not Available
#
#     vteTwitter.1
# 0  Not Available
# 1  Not Available
# 2  Not Available
# 3  Not Available
# 4  Not Available

# %%
counts = df_new.Activity.value_counts() #save the value count output
counts
# Out:
# Musician                                           12
# Musician and actress                                5
# News channel                                        3
# Actor                                               2
# Football player                                     2
# Television personality and businesswoman            2
# Social media platform                               2
# Comedian and television personality                 2
# Sports channel                                      2
# Actor and film producer                             2
# Basketball player                                   1
# Former U.S. president                               1
# Industrial designer and tech entrepreneur           1
# Current Prime Minister of India                     1
# Office of the Prime Minister of India               1
# Space agency                                        1
# Businessman and philanthropist                      1
# Newspaper                                           1
# Current U.S. president                              1
# Football club                                       1
# Television personality, model and businesswoman     1
# Comedian and actor                                  1
# Musician and businesswoman                          1
# Musician and actor                                  1
# Online video platform                               1
# Cricketer                                           1
# Name: Activity, dtype: int64

# %%
largest_categories = counts.head(3).index #get the index of the head()
largest_categories
# Out:
# Index(['Musician', 'Musician and actress', 'News channel'], dtype='object')

# %%
#Use that index with isin() to filter the DataFrame
df_filtered = df_new[df_new.Activity.isin(largest_categories)].head()
df_filtered.drop(['vteTwitter', 'Change (monthly)','vteTwitter.1'], axis='columns')
# Out:
#    Rank    Account name          Owner  Followers (millions)  \
# 1   2.0   @justinbieber  Justin Bieber                 112.0
# 2   3.0      @katyperry     Katy Perry                 108.0
# 5   6.0  @taylorswift13   Taylor Swift                  86.0
# 7   8.0       @ladygaga      Lady Gaga                  82.0
# 9  10.0   @ArianaGrande  Ariana Grande                  76.0
#
#                Activity
# 1              Musician
# 2              Musician
# 5              Musician
# 7              Musician
# 9  Musician and actress

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry')
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
#Are you trying to filter a DataFrame using lots of criteria? It can be hard to write Pencil and to read! Left-pointing magnifying glass

#Instead, save the criteria as objects and use them to filter. Or, use reduce() to combine the criteria!

#save criteria as objects and use them to filter

crit1 = drinks.continent== 'Africa'
crit2 = drinks.beer_servings>100
crit3 = drinks.spirit_servings<200
crit4 = drinks.wine_servings>50

# %%
drinks_filtered = drinks[crit1 & crit2 & crit3 & crit4]
drinks_filtered
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 62          Gabon            347               98             59
# 152    Seychelles            157               25             51
# 159  South Africa            225               76             81
#
#      total_litres_of_pure_alcohol continent
# 62                            8.9    Africa
# 152                           4.1    Africa
# 159                           8.2    Africa

# %%
#use reduce to combine the criteria

from functools import reduce
criteria = reduce(lambda x, y: x & y, [crit1, crit2, crit3, crit4])

# %%
drinks[criteria]
# Out:
#           country  beer_servings  spirit_servings  wine_servings  \
# 62          Gabon            347               98             59
# 152    Seychelles            157               25             51
# 159  South Africa            225               76             81
#
#      total_litres_of_pure_alcohol continent
# 62                            8.9    Africa
# 152                           4.1    Africa
# 159                           8.2    Africa

# %%
#Want to filter a DataFrame that doesn't have a name?

#Use the query() method to avoid creating an intermediate variable!

stocks = pd.read_csv('http://bit.ly/smallstocks', parse_dates = True)
stocks.head()
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT

# %%
#lets say we want to filter the data frame to show close<100
stocks.groupby('Symbol')['Close'].mean().reset_index()
# Out:
#   Symbol       Close
# 0   AAPL  112.856667
# 1   CSCO   31.480000
# 2   MSFT   57.433333

# %%
stocks.groupby('Symbol').mean().query('Close<100')
# Out:
#             Close        Volume
# Symbol
# CSCO    31.480000  1.477983e+07
# MSFT    57.433333  1.866727e+07

# %%
#Need to refer to a local variable within a query() string? Just prefix it with the @ symbol!
stocks
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT
# 5  2016-10-04   31.35  18460400   CSCO
# 6  2016-10-05   57.64  16726400   MSFT
# 7  2016-10-05   31.59  11808600   CSCO
# 8  2016-10-05  113.05  21453100   AAPL

# %%
mean_volume = stocks.Volume.mean()
mean_close = stocks.Close.mean()

# %%
stocks.query('Volume < @mean_volume')
# Out:
#          Date  Close    Volume Symbol
# 0  2016-10-03  31.50  14070500   CSCO
# 2  2016-10-03  57.42  19189500   MSFT
# 5  2016-10-04  31.35  18460400   CSCO
# 6  2016-10-05  57.64  16726400   MSFT
# 7  2016-10-05  31.59  11808600   CSCO

# %%
stocks.query('Close > @mean_close')
# Out:
#          Date   Close    Volume Symbol
# 1  2016-10-03  112.52  21701800   AAPL
# 3  2016-10-04  113.00  29736800   AAPL
# 8  2016-10-05  113.05  21453100   AAPL

# %%
#If you want to use query() on a column name containing a space, just surround it with backticks! (New in pandas 0.25)

#lets rename stock table on the Close column

stock_rename = stocks.rename(columns = {'Close': 'Close of Stock'})
stock_rename
# Out:
#          Date  Close of Stock    Volume Symbol
# 0  2016-10-03           31.50  14070500   CSCO
# 1  2016-10-03          112.52  21701800   AAPL
# 2  2016-10-03           57.42  19189500   MSFT
# 3  2016-10-04          113.00  29736800   AAPL
# 4  2016-10-04           57.24  20085900   MSFT
# 5  2016-10-04           31.35  18460400   CSCO
# 6  2016-10-05           57.64  16726400   MSFT
# 7  2016-10-05           31.59  11808600   CSCO
# 8  2016-10-05          113.05  21453100   AAPL

# %%
stock_rename.query('`Close of Stock` > 100')
# Out:
#          Date  Close of Stock    Volume Symbol
# 1  2016-10-03          112.52  21701800   AAPL
# 3  2016-10-04          113.00  29736800   AAPL
# 8  2016-10-05          113.05  21453100   AAPL

# %%
#Want to concatenate two string columns?

#Option 1: Use a string method Yarn

ufo = pd.read_csv('http://bit.ly/uforeports')
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
#Concatenate with str.cat()

ufo.City.str.cat(ufo.State, sep = ', ').head()
# Out:
# 0                  Ithaca, NY
# 1             Willingboro, NJ
# 2                 Holyoke, CO
# 3                 Abilene, KS
# 4    New York Worlds Fair, NY
# Name: City, dtype: object

# %%
#Option 2: Use plus signs 
#Concatenante with plus sign
ufo_cat = ufo.City + ' ,' + ufo.State

# %%
ufo_cat.head()
# Out:
# 0                  Ithaca ,NY
# 1             Willingboro ,NJ
# 2                 Holyoke ,CO
# 3                 Abilene ,KS
# 4    New York Worlds Fair ,NY
# dtype: object

# %%
#Need to split a string into multiple columns? 

#Use str.split() method, expand=True to return a DataFrame, and assign it to the original DataFrame.

names = pd.DataFrame({'name': ['Abiodun Adetola Joshua', 'Micah Ademuyiwa John'], 'location': ['lagos, Nigeria', 'Port Harcourt, Nigeria']})

# %%
names
# Out:
#                      name                location
# 0  Abiodun Adetola Joshua          lagos, Nigeria
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria

# %%
#Split Name column into first, middle and last name
names[['First name', 'Middle Name', 'Last Name']] = names.name.str.split(' ', expand = True)

names
# Out:
#                      name                location First name Middle Name  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   Last Name
# 0    Joshua
# 1      John

# %%
#Split location and Keep City
names['City'] = names.location.str.split(', ', expand =True)[0]
names
# Out:
#                      name                location First name Middle Name  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   Last Name           City
# 0    Joshua          lagos
# 1      John  Port Harcourt

# %%
names['Country'] = names.location.str.split(', ', expand = True)[1]
names
# Out:
#                      name                location First name Middle Name  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   Last Name           City  Country
# 0    Joshua          lagos  Nigeria
# 1      John  Port Harcourt  Nigeria

# %%
names.drop(columns = 'City')
# Out:
#                      name                location First name Middle Name  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   Last Name  Country
# 0    Joshua  Nigeria
# 1      John  Nigeria

# %%
names.rename(columns = str.upper)
# Out:
#                      NAME                LOCATION FIRST NAME MIDDLE NAME  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   LAST NAME           CITY  COUNTRY
# 0    Joshua          lagos  Nigeria
# 1      John  Port Harcourt  Nigeria

# %%
#How to count the no of words in a series
names['word count'] = names.location.str.split().str.len()
names
# Out:
#                      name                location First name Middle Name  \
# 0  Abiodun Adetola Joshua          lagos, Nigeria    Abiodun     Adetola
# 1    Micah Ademuyiwa John  Port Harcourt, Nigeria      Micah   Ademuyiwa
#
#   Last Name           City  Country  word count
# 0    Joshua          lagos  Nigeria           2
# 1      John  Port Harcourt  Nigeria           3

# %%
#Select columns by data type
df_new.head()
# Out:
#    Rank  Change (monthly)    Account name          Owner  \
# 0   1.0               NaN    @BarackObama   Barack Obama
# 1   2.0               NaN   @justinbieber  Justin Bieber
# 2   3.0               NaN      @katyperry     Katy Perry
# 3   4.0               NaN        @rihanna        Rihanna
# 4   5.0               NaN  @taylorswift13   Taylor Swift
#
#    Followers (millions)                    Activity Country     vteTwitter  \
# 0                 115.0       Former U.S. president     USA  Not Available
# 1                 111.0                    Musician     CAN  Not Available
# 2                 109.0                    Musician     USA  Not Available
# 3                  96.0  Musician and businesswoman     BAR  Not Available
# 4                  86.0                    Musician     USA  Not Available
#
#     vteTwitter.1
# 0  Not Available
# 1  Not Available
# 2  Not Available
# 3  Not Available
# 4  Not Available

# %%
df_new.select_dtypes(include='number').head()
# Out:
#    Rank  Change (monthly)  Followers (millions)
# 0   1.0               NaN                 115.0
# 1   2.0               NaN                 111.0
# 2   3.0               NaN                 109.0
# 3   4.0               NaN                  96.0
# 4   5.0               NaN                  86.0

# %%
df_new.select_dtypes(include=['object']).head()
# Out:
#      Account name          Owner                    Activity Country  \
# 0    @BarackObama   Barack Obama       Former U.S. president     USA
# 1   @justinbieber  Justin Bieber                    Musician     CAN
# 2      @katyperry     Katy Perry                    Musician     USA
# 3        @rihanna        Rihanna  Musician and businesswoman     BAR
# 4  @taylorswift13   Taylor Swift                    Musician     USA
#
#       vteTwitter   vteTwitter.1
# 0  Not Available  Not Available
# 1  Not Available  Not Available
# 2  Not Available  Not Available
# 3  Not Available  Not Available
# 4  Not Available  Not Available

# %%
df_new.dtypes
# Out:
# Rank                    float64
# Change (monthly)        float64
# Account name             object
# Owner                    object
# Followers (millions)    float64
# Activity                 object
# Country                  object
# vteTwitter               object
# vteTwitter.1             object
# dtype: object
