# %%
import pandas as pd
import seaborn as sns

# %%
staff_tips = sns.load_dataset('tips')
staff_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Generate a histogram for the tips column.

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (4,3) 
staff_tips.tip.plot(kind='hist')
#plt.show() # use this in a text editor.

# %%
day_counts = staff_tips.day.value_counts()

# %%
day_counts.plot(kind='bar')

# %%
staff_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='day', data=tips)

# %%
sns.distplot(tips.total_bill)

# %%
a = tips.head()

# %%
sns.distplot(tips.total_bill, kde=False)

# %%
staff_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# Display a Lineplot of total bill against tip.

# %%
sns.lmplot(x = 'total_bill', y='tip', data=staff_tips, hue ='sex')

# %%
sns.lmplot(x = 'total_bill', y='tip', data=staff_tips,
           hue ='sex', fit_reg=False)

# %%
sns.lmplot(x = 'total_bill', y='tip', data=tips,
           hue ='sex', fit_reg=False,
          col='time', row='smoker')

# %% [markdown]
# How do we create a facet grid in seaborn

# %%
facet = sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
#use matplotlib funtion in seaborn
facet.map(plt.scatter, 'total_bill', 'tip')

# %%
fig, ax = plt.subplots(1,1)
ax.scatter(tips.tip, tips.total_bill)

# %%
fig, (ax1, ax2) = plt.subplots(1,2)
ax1.scatter(tips.tip, tips.total_bill)
ax2.hist(tips.total_bill)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
dis = sns.distplot(tips.tip)

# %% [markdown]
# lets say we wan tot use seaborn instead of matplot lib for the figures ax plotting

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
sns.distplot(tips.tip, ax=ax1)
sns.regplot(x='total_bill', y='tip', data=tips, ax=ax2)
sns.barplot(x='smoker', y='tip', data=tips, hue='sex')
