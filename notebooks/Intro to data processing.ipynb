# %%
import pandas as pd
data = pd.read_csv('../Data/gapminder.tsv', sep='\t')
from pandas_profiling import ProfileReport
report = ProfileReport(data, minimal=False, progress_bar=True)
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "C:\Users\SAMSUNG 930X 15\Anaconda3\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "C:\Users\SAMSUNG 930X 15\Anaconda3\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "C:\Users\SAMSUNG 930X 15\Anaconda3\lib\site-packages\pandas_profiling\describe.py", line 282, in multiprocess_func
#     return x[0], describe_1d(x[1], **kwargs)
#   File "C:\Users\SAMSUNG 930X 15\Anaconda3\lib\site-packages\pandas_profiling\describe.py", line 270, in describe_1d
#     result = result.append(describe_numeric_1d(data, **kwargs))
#   File "C:\Users\SAMSUNG 930X 15\Anaconda3\lib\site-packages\pandas_profiling\describe.py", line 54, in describe_numeric_1d
# ...

# %%
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df = pd.read_csv('../Data/gapminder.tsv', sep='\t')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# to subset columns
country = df['country']

# %%
country
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
type(country)
# Out:
# pandas.core.series.Series

# %%
#To convert the series to a data frame object
country = df[['country']]

# %%
country
# Out:
#           country
# 0     Afghanistan
# 1     Afghanistan
# 2     Afghanistan
# 3     Afghanistan
# 4     Afghanistan
# ...           ...
# 1699     Zimbabwe
# 1700     Zimbabwe
# 1701     Zimbabwe
# 1702     Zimbabwe
# 1703     Zimbabwe
#
# [1704 rows x 1 columns]

# %%
# How to drop certain columns in the data set
#lets say we want to drop the country, year and continent columns

df.drop(['continent', 'country', 'year'], axis='columns')
# Out:
#       lifeExp       pop   gdpPercap
# 0      28.801   8425333  779.445314
# 1      30.332   9240934  820.853030
# 2      31.997  10267083  853.100710
# 3      34.020  11537966  836.197138
# 4      36.088  13079460  739.981106
# ...       ...       ...         ...
# 1699   62.351   9216418  706.157306
# 1700   60.377  10704340  693.420786
# 1701   46.809  11404948  792.449960
# 1702   39.989  11926563  672.038623
# 1703   43.487  12311143  469.709298
#
# [1704 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
df_dropped = df.drop(['continent', 'country', 'year'], axis='columns')

# %%
# How do we Subset rows:
df.loc[0] #for first row
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
df.loc[[0,1]] # This is string match to the index Label
df.loc[[0,1200]]
# Out:
#           country continent  year  lifeExp      pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801  8425333   779.445314
# 1200         Peru  Americas  1952   43.902  8025700  3758.523437

# %%
df.iloc[[0,1,-1]] # This is the acual index position and not index label. This is quite usefu in Scikit Learn
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#Select the First Five rows, the country, year and lifeExp columns
subset = df.loc[[0,1,2,3,4], ['country', 'year', 'lifeExp']]

# %%
subset
# Out:
#        country  year  lifeExp
# 0  Afghanistan  1952   28.801
# 1  Afghanistan  1957   30.332
# 2  Afghanistan  1962   31.997
# 3  Afghanistan  1967   34.020
# 4  Afghanistan  1972   36.088

# %%
#Alteratively, you can also use iloc
#This uses the index position of the rows and columns
subset_2 = df.iloc[[0,1,2,3,4,5], [0,2,3]]

# %%
subset_2
# Out:
#        country  year  lifeExp
# 0  Afghanistan  1952   28.801
# 1  Afghanistan  1957   30.332
# 2  Afghanistan  1962   31.997
# 3  Afghanistan  1967   34.020
# 4  Afghanistan  1972   36.088
# 5  Afghanistan  1977   38.438

# %%
#BOOLEAN CONDITIONS
#for instance we want to get info about united states in the data
df.loc[df['country']=='United States']
# Out:
#             country continent  year  lifeExp        pop    gdpPercap
# 1608  United States  Americas  1952   68.440  157553000  13990.48208
# 1609  United States  Americas  1957   69.490  171984000  14847.12712
# 1610  United States  Americas  1962   70.210  186538000  16173.14586
# 1611  United States  Americas  1967   70.760  198712000  19530.36557
# 1612  United States  Americas  1972   71.340  209896000  21806.03594
# 1613  United States  Americas  1977   73.380  220239000  24072.63213
# 1614  United States  Americas  1982   74.650  232187835  25009.55914
# 1615  United States  Americas  1987   75.020  242803533  29884.35041
# 1616  United States  Americas  1992   76.090  256894189  32003.93224
# 1617  United States  Americas  1997   76.810  272911760  35767.43303
# 1618  United States  Americas  2002   77.310  287675526  39097.09955
# 1619  United States  Americas  2007   78.242  301139947  42951.65309

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
#Lets say we want to access a particular year in the data for Zimbabwe only
df.loc[(df['country']=='Zimbabwe') & (df['year']==1977)]
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 1697  Zimbabwe    Africa  1977   57.674  6642107  685.587682

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
#Let us determine the average gdpPercap for each year.
df.groupby(['year'])['lifeExp'].mean().reset_index()
# Out:
#     year    lifeExp
# 0   1952  49.057620
# 1   1957  51.507401
# 2   1962  53.609249
# 3   1967  55.678290
# 4   1972  57.647386
# 5   1977  59.570157
# 6   1982  61.533197
# 7   1987  63.212613
# 8   1992  64.160338
# 9   1997  65.014676
# 10  2002  65.694923
# 11  2007  67.007423

# %%
import numpy as np
df.groupby(['year'])['lifeExp'].agg(np.std)
# Out:
# year
# 1952    12.225956
# 1957    12.231286
# 1962    12.097245
# 1967    11.718858
# 1972    11.381953
# 1977    11.227229
# 1982    10.770618
# 1987    10.556285
# 1992    11.227380
# 1997    11.559439
# 2002    12.279823
# 2007    12.073021
# Name: lifeExp, dtype: float64

# %%
df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
#df.groupby(['year', 'continent'])['gdpPercap'].mean()
df.groupby(['year', 'continent'])['gdpPercap'].agg(np.std)
# Out:
# year  continent
# 1952  Africa         982.952116
#       Americas      3001.727522
#       Asia         18634.890865
#       Europe        3114.060493
#       Oceania        365.560078
# 1957  Africa        1134.508918
#       Americas      3312.381083
#       Asia         19506.515959
#       Europe        3677.950146
#       Oceania        917.644806
# 1962  Africa        1461.839189
#       Americas      3421.740569
#       Asia         16415.857196
#       Europe        4199.193906
#       Oceania        677.727301
# 1967  Africa        2847.717603
#       Americas      4160.885560
#       Asia         14062.591362
#       Europe        4724.983889
#       Oceania         43.986086
# 1972  Africa        3286.853884
#       Americas      4754.404329
#       Asia         19087.502918
#       Europe        5509.691411
#       Oceania        525.091980
# 1977  Africa        4142.398707
#       Americas      5355.602518
#       Asia         11815.777923
# ...

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].mean()
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %%
df.groupby(['year', 'continent'])[['lifeExp', 'gdpPercap']].agg(np.mean).reset_index()
# Out:
#     year continent    lifeExp     gdpPercap
# 0   1952    Africa  39.135500   1252.572466
# 1   1952  Americas  53.279840   4079.062552
# 2   1952      Asia  46.314394   5195.484004
# 3   1952    Europe  64.408500   5661.057435
# 4   1952   Oceania  69.255000  10298.085650
# 5   1957    Africa  41.266346   1385.236062
# 6   1957  Americas  55.960280   4616.043733
# 7   1957      Asia  49.318544   5787.732940
# 8   1957    Europe  66.703067   6963.012816
# 9   1957   Oceania  70.295000  11598.522455
# 10  1962    Africa  43.319442   1598.078825
# 11  1962  Americas  58.398760   4901.541870
# 12  1962      Asia  51.563223   5729.369625
# 13  1962    Europe  68.539233   8365.486814
# 14  1962   Oceania  71.085000  12696.452430
# 15  1967    Africa  45.334538   2050.363801
# 16  1967  Americas  60.410920   5668.253496
# 17  1967      Asia  54.663640   5971.173374
# 18  1967    Europe  69.737600  10143.823757
# 19  1967   Oceania  71.310000  14495.021790
# ...

# %%
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
sample_df = df.loc[((df.continent == "Africa" ) 
                    & (df.lifeExp > 55 ) 
                    & (df.year == 2002) 
                    & (df.gdpPercap > 8000))]

# %%
sample_df
# Out:
#        country continent  year  lifeExp      pop     gdpPercap
# 550      Gabon    Africa  2002   56.761  1299304  12521.713920
# 910      Libya    Africa  2002   72.737  5368585   9534.677467
# 982  Mauritius    Africa  2002   71.954  1200206   9021.815894

# %%
import pandas as pd

# %%
data = {'GIIP':[94,155,46,75,69,113,36,58], 
        'Prob':[0.18,0.12,0.12,0.08,0.18,0.12,0.12,0.08]}
df = pd.DataFrame(data)
df
# Out:
#    GIIP  Prob
# 0    94  0.18
# 1   155  0.12
# 2    46  0.12
# 3    75  0.08
# 4    69  0.18
# 5   113  0.12
# 6    36  0.12
# 7    58  0.08

# %%
df.sort_values(['GIIP', 'Prob'],axis=0,ascending=False,inplace=True)
df
# Out:
#    GIIP  Prob
# 1   155  0.12
# 5   113  0.12
# 0    94  0.18
# 3    75  0.08
# 4    69  0.18
# 7    58  0.08
# 2    46  0.12
# 6    36  0.12

# %%
df['um_prob'] = df['Prob'].cumsum()
df
# Out:
#    GIIP  Prob  cum_prob  Cum_prob
# 1   155  0.12      0.12      0.12
# 5   113  0.12      0.24      0.24
# 0    94  0.18      0.42      0.42
# 3    75  0.08      0.50      0.50
# 4    69  0.18      0.68      0.68
# 7    58  0.08      0.76      0.76
# 2    46  0.12      0.88      0.88
# 6    36  0.12      1.00      1.00

# %%
df.plot(x='GIIP', y='cum_prob', 
        figsize=(8,5), legend=False, style='ko-.', label="Probability values")
plt.title("Probability distribution of Inplace Volumes", y=1.01, fontsize=20)
plt.ylabel("Cumulative probability", labelpad=15)
plt.xlabel("GIIP", labelpad=15)
plt.xlim(0,200)
plt.legend();

# %%
df
# Out:
#    GIIP  Prob  cum_prob  Cum_prob
# 1   155  0.12      0.12      0.12
# 5   113  0.12      0.24      0.24
# 0    94  0.18      0.42      0.42
# 3    75  0.08      0.50      0.50
# 4    69  0.18      0.68      0.68
# 7    58  0.08      0.76      0.76
# 2    46  0.12      0.88      0.88
# 6    36  0.12      1.00      1.00

# %%
df
# Out:
#    GIIP  Prob  Cum_prob
# 1   155  0.12      0.12
# 5   113  0.12      0.24
# 0    94  0.18      0.42
# 3    75  0.08      0.50
# 4    69  0.18      0.68
# 7    58  0.08      0.76
# 2    46  0.12      0.88
# 6    36  0.12      1.00

# %%
import pandas as pd
data = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_oil_production')
oil_prod = pd.DataFrame(data)
oil_prod
# Out:
#                                                    0
# 0     Unnamed: 0              Country  Oil produc...
# 1              vteLists of countries by energy ra...

# %%
import pandas as pd
pd.read_csv('../Data/covid-data.csv')
# Out:
#       iso_code continent       location        date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  2019-12-31          0.0        0.0
# 1          AFG      Asia    Afghanistan  2020-01-01          0.0        0.0
# 2          AFG      Asia    Afghanistan  2020-01-02          0.0        0.0
# 3          AFG      Asia    Afghanistan  2020-01-03          0.0        0.0
# 4          AFG      Asia    Afghanistan  2020-01-04          0.0        0.0
# ...        ...       ...            ...         ...          ...        ...
# 39899      NaN       NaN  International  2020-08-23        696.0        NaN
# 39900      NaN       NaN  International  2020-08-24        696.0        NaN
# 39901      NaN       NaN  International  2020-08-25        696.0        NaN
# 39902      NaN       NaN  International  2020-08-26        696.0        NaN
# 39903      NaN       NaN  International  2020-08-27        696.0        NaN
#
# ...

# %%
df = pd.DataFrame(np.random.randn(4, 4))
df.style.set_table_styles(
[{'selector': 'tr:hover',
  'props': [('background-color', 'tomato')]}]
)
# Out:
# <style  type="text/css" >
#     #T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758 tr:hover {
#           background-color: tomato;
#     }</style><table id="T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >2</th>        <th class="col_heading level0 col3" >3</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758row0_col0" class="data row0 col0" >0.271237</td>
#                         <td id="T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758row0_col1" class="data row0 col1" >2.391138</td>
#                         <td id="T_e6fcb2f6_e8a5_11ea_a567_24f5aacb8758row0_col2" class="data row0 col2" >0.815637</td>
# ...

# %%
df = pd.DataFrame(
dict(Material=['Silver', 'Copper', 'Gold','Iron'],
       Resistivity_20degC =['1.59E−8','1.68E-8','2.44E-8','1.0E-7' ],
       Conductivity_20degC=['6.30E7','5.96E7','4.10E7','1.0E7']),
columns=['Material', 'Resistivity_20degC','Conductivity_20degC'])
df
# Out:
#   Material Resistivity_20degC Conductivity_20degC
# 0   Silver            1.59E−8              6.30E7
# 1   Copper            1.68E-8              5.96E7
# 2     Gold            2.44E-8              4.10E7
# 3     Iron             1.0E-7               1.0E7

# %%
df.style.set_table_styles(
[{'selector': 'tr:nth-of-type(odd)',
  'props': [('background', '#ffffff')]}, 
 {'selector': 'tr:nth-of-type(even)',
  'props': [('background', 'silver')]},
 {'selector': 'th',
  'props': [('background', '#606060'), 
            ('color', 'white'),
            ('font-family', 'verdana')]},
 {'selector': 'td',
  'props': [('font-family', 'verdana'),]},
]
).hide_index()
# Out:
# <style  type="text/css" >
#     #T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758 tr:nth-of-type(odd) {
#           background: #ffffff;
#     }    #T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758 tr:nth-of-type(even) {
#           background: silver;
#     }    #T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758 th {
#           background: #606060;
#           color: white;
#           font-family: verdana;
#     }    #T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758 td {
#           font-family: verdana;
#     }</style><table id="T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758" ><thead>    <tr>        <th class="col_heading level0 col0" >Material</th>        <th class="col_heading level0 col1" >Resistivity_20degC</th>        <th class="col_heading level0 col2" >Conductivity_20degC</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_96d1de68_e8aa_11ea_b4eb_24f5aacb8758row0_col0" class="data row0 col0" >Silver</td>
# ...

# %%
import pandas as pd
import numpy as np 
df = pd.DataFrame(dict(Menu=['Fried Rice', 'Burger', 'Baked Potatoes', 'Burger', 'Noodles',
                          'French Fries','Fried Rice', 'Baked Potatoes'],
                    Type=['Dinner','Lunch', 'Breakfast', 'Lunch',
                          'Dinner', 'Dinner', 'Lunch', 'Dinner'],
                       Agg_meal =[1,2,3,4,5,6,7,8],
                       Guest_served =[12,10,23,44,37,59,33,43]))
Avail_menu = df.groupby(['Menu','Type']).agg({'Agg_meal': ['max', np.mean],
                                 'Guest_served': ['sum','min','count']})
Avail_menu
# Out:
#                          Agg_meal      Guest_served
#                               max mean          sum min count
# Menu           Type
# Baked Potatoes Breakfast        3    3           23  23     1
#                Dinner           8    8           43  43     1
# Burger         Lunch            4    3           54  10     2
# French Fries   Dinner           6    6           59  59     1
# Fried Rice     Dinner           1    1           12  12     1
#                Lunch            7    7           33  33     1
# Noodles        Dinner           5    5           37  37     1

# %%
df
# Out:
#              Menu       Type  Agg_meal  Guest_served
# 0      Fried Rice     Dinner         1            12
# 1          Burger      Lunch         2            10
# 2  Baked Potatoes  Breakfast         3            23
# 3          Burger      Lunch         4            44
# 4         Noodles     Dinner         5            37
# 5    French Fries     Dinner         6            59
# 6      Fried Rice      Lunch         7            33
# 7  Baked Potatoes     Dinner         8            43

# %%
df.memory_usage(deep=True)
# Out:
# Index           128
# Menu            535
# Type            504
# Agg_meal         64
# Guest_served     64
# dtype: int64

# %%
egg beans = [2,3,4]
# Out:
#   File "<ipython-input-1-0086ad7f1d2f>", line 1
#     egg beans = [2,3,4]
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
df = pd.DataFrame({"X":[20,30,40,50], 
                   "Y":[10,15,20,25],
                   "Z":[30,35,40,45]})
df['Row_Total']     = df.apply(lambda x: x.sum(), axis=1)
df.loc['Cols_Total'] = df.apply(lambda x: x.sum())
df
# Out:
#               X   Y    Z  Row_Total
# 0            20  10   30         60
# 1            30  15   35         80
# 2            40  20   40        100
# 3            50  25   45        120
# Cols_Total  140  70  150        360

# %%
import pandas as pd 
pd.options.display.max_columns = 30 
pd.options.display.max_rows = 100    
pd.options.display.max_colwidth = 50
pd.options.display.precision = 4

# %%
import pandas as pd
df = pd.DataFrame({'Depatures':['GGICO','Emirates', 'Damac', 'Business Bay',
                                'Emirates','Emirates','GGICO'],
                   
                   'Arrivals':['Al Quasis', 'Internet city', 'Palm Deira', 
                               'Burjuman','Burjuman', 'Al Quasis','Baniyas Square'],
                   
                   'Metro':['Green line', 'Red Line', 'Green Line', 'Red Line',
                            'Red Line', 'Green Line', 'Green Line']
                  })

# %%
pd.crosstab(index = [df['Depatures'], df['Metro']],
            columns = [df['Arrivals']],
            rownames = ['Depatures', 'Metro'],
            colnames = ['Arrivals'],
            margins = True
           )
# Out:
# Arrivals                 Al Quasis  Baniyas Square  Burjuman  Internet city  \
# Depatures    Metro
# Business Bay Red Line            0               0         1              0
# Damac        Green Line          0               0         0              0
# Emirates     Green Line          1               0         0              0
#              Red Line            0               0         1              1
# GGICO        Green Line          0               1         0              0
#              Green line          1               0         0              0
# All                              2               1         2              1
#
# Arrivals                 Palm Deira  All
# Depatures    Metro
# Business Bay Red Line             0    1
# Damac        Green Line           1    1
# Emirates     Green Line           0    1
#              Red Line             0    2
# GGICO        Green Line           0    1
#              Green line           0    1
# ...

# %%
data = {'GIIP':[94,155,46,58], 
        'Prob':[0.18,0.12,0.12,0.08]}
df = pd.DataFrame(data)
df
# Out:
#    GIIP  Prob
# 0    94  0.18
# 1   155  0.12
# 2    46  0.12
# 3    58  0.08

# %%
df.idxmin()
# Out:
# GIIP    2
# Prob    3
# dtype: int64

# %%
df.idxmax()
# Out:
# GIIP    1
# Prob    0
# dtype: int64
